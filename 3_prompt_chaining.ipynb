# %% [markdown]
# # propmt chaining
#
# START -> GEN_OUTLINE -> GEN_BLOG -> END

# %%
from langgraph.graph import StateGraph, START, END
from langchain_openai import ChatOpenAI
from typing import TypedDict
from dotenv import load_dotenv

# %%
load_dotenv()

model = ChatOpenAI()

# %%
class BlogState(TypedDict):
    
    title: str
    outline: str
    content: str

# %%
def create_outline(state: BlogState) -> BlogState:
    """Generate an outline for a blog post."""
    
    title = state['title']
    
    prompt = f'Generate a detailed outline for a blog on the topic: {title}'
    outline = model.invoke(prompt).content

    state['outline'] = outline
    
    return state

# %%
def create_blog(state: BlogState) -> BlogState:
    """Generate a blog post based on the outline."""
    
    title = state['title']
    outline = state['outline']
    
    prompt = f'Write a detailed blog on title - {title} using the following outline:\n{outline}'
    content = model.invoke(prompt).content

    state['content'] = content
    
    return state

# %%
graph = StateGraph(BlogState)

#nodes
graph.add_node('create_ouline', create_outline)
graph.add_node('create_blog', create_blog)

#edges
graph.add_edge(START, 'create_ouline')
graph.add_edge('create_ouline', 'create_blog')
graph.add_edge('create_blog', END)

workflow = graph.compile()

# %%
initial_state = {'title':'rise of AI in india'}

final_state = workflow.invoke(initial_state)

print(final_state)
# Out:
# {'title': 'rise of AI in india', 'outline': "I. Introduction\n    A. Definition of AI (Artificial Intelligence)\n    B. Explanation of the rise of AI in India\n    C. Purpose of the blog\n\nII. Historical Background of AI in India\n    A. Early developments in AI technology in India\n    B. Government initiatives to promote AI research and development\n    C. Role of Indian startups in the AI sector\n\nIII. Current State of AI in India\n    A. Major industries adopting AI technology\n    B. Impact of AI on the Indian economy\n    C. Challenges faced by the AI industry in India\n\nIV. Key Players in the Indian AI Sector\n    A. Leading AI companies in India\n    B. Collaboration between Indian and international AI firms\n    C. Role of educational institutions in fostering AI talent\n\nV. Future Prospects of AI in India\n    A. Growth potential of the AI sector in India\n    B. Opportunities for AI professionals in India\n    C. Impact of AI on society and workforce in India\n\nVI. Case Studies\n    A. Successful AI implementation in Indian businesses\n    B. AI projects by Indian government agencies\n    C. AI-powered innovations in Indian healthcare and education sectors\n\nVII. Ethical Considerations\n    A. Privacy concerns related to AI technology in India\n    B. Ethical implications of AI in decision-making processes\n    C. Measures to ensure responsible AI development in India\n\nVIII. Conclusion\n    A. Recap of the rise of AI in India\n    B. Importance of AI technology in India's future\n    C. Call to action for promoting AI awareness and education in India.", 'content': "I. Introduction\n\nA. Definition of AI (Artificial Intelligence)\n\nArtificial Intelligence, commonly known as AI, is the simulation of human intelligence processes by machines, especially computer systems. These processes include learning, reasoning, problem-solving, perception, and language understanding. AI has the potential to revolutionize various industries by automating tasks, increasing efficiency, and providing valuable insights through data analysis.\n\nB. Explanation of the rise of AI in India\n\nIn recent years, India has emerged as a hub for AI innovation and development. With a growing tech-savvy population, a strong software industry, and government support, the country has seen a surge in AI research, investments, and startups. India's large pool of talented engineers and data scientists has also contributed to the rise of AI in the country.\n\nC. Purpose of the blog\n\nThis blog aims to explore the historical background, current state, key players, future prospects, and ethical considerations of AI in India. By analyzing the trends and developments in the Indian AI sector, we can better understand the impact of AI on the country's economy, society, and workforce.\n\nII. Historical Background of AI in India\n\nA. Early developments in AI technology in India\n\nIndia has a long history of AI research dating back to the 1980s. The Department of Electronics established the Center for Artificial Intelligence and Robotics (CAIR) in Bangalore to promote research in AI and robotics. Indian scientists and researchers have made significant contributions to the field of AI, particularly in areas like natural language processing, machine learning, and computer vision.\n\nB. Government initiatives to promote AI research and development\n\nThe Indian government has recognized the potential of AI in driving economic growth and has launched several initiatives to support AI research and development. The National Artificial Intelligence Mission (N-AIM) aims to create a vibrant AI ecosystem in India by promoting research, innovation, and adoption of AI technologies across various sectors.\n\nC. Role of Indian startups in the AI sector\n\nIndian startups have played a crucial role in the growth of the AI sector in the country. Companies like Flipkart, Paytm, and Zomato have leveraged AI technology to improve their products and services, enhance cust ...

# %%
print(final_state['outline'])
# Out:
# I. Introduction
#     A. Definition of AI (Artificial Intelligence)
#     B. Explanation of the rise of AI in India
#     C. Purpose of the blog
#
# II. Historical Background of AI in India
#     A. Early developments in AI technology in India
#     B. Government initiatives to promote AI research and development
#     C. Role of Indian startups in the AI sector
#
# III. Current State of AI in India
#     A. Major industries adopting AI technology
#     B. Impact of AI on the Indian economy
#     C. Challenges faced by the AI industry in India
#
# IV. Key Players in the Indian AI Sector
#     A. Leading AI companies in India
#     B. Collaboration between Indian and international AI firms
#     C. Role of educational institutions in fostering AI talent
#
# V. Future Prospects of AI in India
#     A. Growth potential of the AI sector in India
#     B. Opportunities for AI professionals in India
#     C. Impact of AI on society and workforce in India
#
# VI. Case Studies
#     A. Successful AI implementation in Indian businesses
#     B. AI projects by Indian government agencies
#     C. AI-powered innovations in Indian healthcare and education sectors
#
# VII. Ethical Considerations
#     A. Privacy concerns related to AI technology in India
#     B. Ethical implications of AI in decision-making processes
#     C. Measures to ensure responsible AI development in India
#
# VIII. Conclusion
#     A. Recap of the rise of AI in India
#     B. Importance of AI technology in India's future
#     C. Call to action for promoting AI awareness and education in India.

# %%
print(final_state['content'])
# Out:
# I. Introduction
#
# A. Definition of AI (Artificial Intelligence)
#
# Artificial Intelligence, commonly known as AI, is the simulation of human intelligence processes by machines, especially computer systems. These processes include learning, reasoning, problem-solving, perception, and language understanding. AI has the potential to revolutionize various industries by automating tasks, increasing efficiency, and providing valuable insights through data analysis.
#
# B. Explanation of the rise of AI in India
#
# In recent years, India has emerged as a hub for AI innovation and development. With a growing tech-savvy population, a strong software industry, and government support, the country has seen a surge in AI research, investments, and startups. India's large pool of talented engineers and data scientists has also contributed to the rise of AI in the country.
#
# C. Purpose of the blog
#
# This blog aims to explore the historical background, current state, key players, future prospects, and ethical considerations of AI in India. By analyzing the trends and developments in the Indian AI sector, we can better understand the impact of AI on the country's economy, society, and workforce.
#
# II. Historical Background of AI in India
#
# A. Early developments in AI technology in India
#
# India has a long history of AI research dating back to the 1980s. The Department of Electronics established the Center for Artificial Intelligence and Robotics (CAIR) in Bangalore to promote research in AI and robotics. Indian scientists and researchers have made significant contributions to the field of AI, particularly in areas like natural language processing, machine learning, and computer vision.
#
# B. Government initiatives to promote AI research and development
#
# The Indian government has recognized the potential of AI in driving economic growth and has launched several initiatives to support AI research and development. The National Artificial Intelligence Mission (N-AIM) aims to create a vibrant AI ecosystem in India by promoting research, innovation, and adoption of AI technologies across various sectors.
#
# C. Role of Indian startups in the AI sector
#
# Indian startups have played a crucial role in the growth of the AI sector in the country. Companies like Flipkart, Paytm, and Zomato have leveraged AI technology to improve their products and services, enhance customer experiences, and drive business growth. These startups have also attracted investments from both domestic and international investors, further fueling the growth of the AI industry in India.
#
# III. Current State of AI in India
#
# A. Major industries adopting AI technology
#
# AI technology has been widely adopted across various industries in India, including healthcare, finance, e-commerce, agriculture, and manufacturing. Companies are using AI for predictive analytics, customer segmentation, fraud detection, inventory management, and personalized recommendations, among other applications.
#
# B. Impact of AI on the Indian economy
#
# The adoption of AI technology is expected to have a significant impact on the Indian economy. According to a report by NASSCOM, AI has the potential to add $957 billion to India's GDP by 2035. AI-powered automation could also lead to job displacement in certain sectors, but new job opportunities are likely to emerge in AI research, development, and implementation.
#
# C. Challenges faced by the AI industry in India
#
# Despite the rapid growth of the AI sector in India, there are several challenges that need to be addressed. These include a shortage of skilled AI professionals, data privacy concerns, ethical issues related to AI algorithms, and the need for regulatory frameworks to govern AI technologies. The Indian government and industry stakeholders are working to address these challenges and create a conducive environment for AI innovation.
#
# IV. Key Players in the Indian AI Sector
#
# A. Leading AI companies in India
#
# Several Indian companies have emerged as key players in the AI sector, offering a wide range of AI solutions and services. Companies like Wipro, TCS, Infosys, and Tech Mahindra have set up AI labs and research centers to drive innovation in AI technologies. Startups like Niramai, SigTuple, and Mad Street Den are also making a mark in the AI space with their cutting-edge solutions.
#
# B. Collaboration between Indian and international AI firms
#
# Indian AI companies are collaborating with international firms to leverage their expertise, technologies, and resources. Partnerships and collaborations between Indian and foreign companies are driving innovation in AI research and development, and helping Indian firms gain a competitive edge in the global AI market.
#
# C. Role of educational institutions in fostering AI talent
#
# Indian educational institutions are playing a crucial role in nurturing AI talent and fostering innovation in the AI sector. Institutes like IITs, IIITs, and research centers like IISc are offering specialized courses in AI, machine learning, and data science to train the next generation of AI professionals. Industry-academia collaborations are also helping bridge the skills gap in the AI industry.
#
# V. Future Prospects of AI in India
#
# A. Growth potential of the AI sector in India
#
# The AI sector in India is poised for exponential growth in the coming years, driven by advancements in AI technologies, increasing investments, and rising demand for AI solutions. India has the potential to become a global AI powerhouse and a hub for AI innovation, research, and development.
#
# B. Opportunities for AI professionals in India
#
# The growing demand for AI professionals in India presents exciting career opportunities for engineers, data scientists, AI researchers, and AI consultants. The AI sector offers competitive salaries, challenging projects, and opportunities for growth and advancement. Indian professionals have the opportunity to work on cutting-edge AI projects and make a meaningful impact on society.
#
# C. Impact of AI on society and workforce in India
#
# The widespread adoption of AI technology in India is expected to have a transformative impact on society and the workforce. AI-powered automation could lead to job displacement in certain sectors, but it is also likely to create new job opportunities in AI research, development, and implementation. AI has the potential to improve efficiency, productivity, and innovation across various industries, leading to economic growth and societal development.
#
# VI. Case Studies
#
# A. Successful AI implementation in Indian businesses
#
# Several Indian businesses have successfully implemented AI technology to drive business growth and enhance customer experiences. Companies like Ola, Swiggy, and Jio are using AI for route optimization, food delivery, and personalized recommendations, respectively. These AI-powered solutions have helped these companies gain a competitive edge in their respective industries.
#
# B. AI projects by Indian government agencies
#
# Government agencies in India are also leveraging AI technology to improve governance, public services, and decision-making processes. The National Health Authority (NHA) is using AI for fraud detection in the Ayushman Bharat scheme, while the Unique Identification Authority of India (UIDAI) is using AI for biometric authentication. These AI projects are helping government agencies enhance efficiency, transparency, and accountability.
#
# C. AI-powered innovations in Indian healthcare and education sectors
#
# The healthcare and education sectors in India are witnessing significant AI-powered innovations to improve service delivery and outcomes. AI-based diagnostic solutions like NIRAMAI are helping in early detection of breast cancer, while AI-powered learning platforms like BYJU'S are revolutionizing education by offering personalized learning experiences. These innovations have the potential to transform the healthcare and education landscape in India.
#
# VII. Ethical Considerations
#
# A. Privacy concerns related to AI technology in India
#
# The widespread use of AI technology in India raises concerns about data privacy and security. AI algorithms rely on vast amounts of data to make predictions and recommendations, raising issues related to data protection, consent, and transparency. The Indian government and industry stakeholders need to implement robust data protection laws and ethical guidelines to safeguard individuals' privacy rights.
#
# B. Ethical implications of AI in decision-making processes
#
# AI algorithms are increasingly being used in decision-making processes in various sectors, including finance, healthcare, and law enforcement. These AI systems can be biased, opaque, and prone to errors, leading to ethical dilemmas and societal implications. It is important to ensure that AI algorithms are fair, transparent, and accountable in their decision-making processes.
#
# C. Measures to ensure responsible AI development in India
#
# To address the ethical considerations of AI technology in India, there is a need for responsible AI development practices. This includes developing ethical AI frameworks, promoting transparency and accountability in AI algorithms, and fostering a culture of responsible AI innovation. Government regulations, industry standards, and public awareness campaigns can help ensure that AI technology is used ethically and responsibly in India.
#
# VIII. Conclusion
#
# A. Recap of the rise of AI in India
#
# The rise of AI in India has been fueled by technological advancements, government support, industry collaborations, and a talented workforce. The country's AI sector is witnessing rapid growth and innovation, with opportunities for professionals, businesses, and society as a whole.
#
# B. Importance of AI technology in India's future
#
# AI technology is expected to play a crucial role in shaping India's future economy, society, and workforce. From driving innovation and productivity to enhancing decision-making and service delivery, AI has the potential to transform various aspects of Indian society and contribute to economic growth and development.
#
# C. Call to action for promoting AI awareness and education in India
#
# As India continues to embrace AI technology, there is a need for greater awareness, education, and collaboration to unlock the full potential of AI. By promoting AI literacy, fostering industry-academia partnerships, and encouraging responsible AI development, India can position itself as a global AI powerhouse and lead the way in shaping a technologically advanced and ethically responsible future.
